# %% [markdown]
# # symlink

# %%
base_name = 'zhudl'
commend = f'/share/home/liushuo/.conda/envs/npr/bin/python /share/data/CryoET_Data/liushuo/code/slurm/pack_symlinks.py -r /share/data/CryoET_Data/{base_name}/ -o /share/data/CryoET_Data/user_symlink/{base_name}_symlinks.tar'
print(commend)
# Out:
# /share/home/liushuo/.conda/envs/npr/bin/python /share/data/CryoET_Data/liushuo/code/slurm/pack_symlinks.py -r /share/data/CryoET_Data/zhudl/ -o /share/data/CryoET_Data/user_symlink/zhudl_symlinks.tar

# %% [markdown]
# # failed

# %%
base_name = 'chongli'
